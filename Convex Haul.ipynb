# %%
import matplotlib.pyplot as plt
import numpy as np

l0 = [(10, 244), (10, 300), (11, 276), (11, 279), (12, 213), (12, 229), (12, 299), (13, 259), (15, 236), (15, 251), (16, 227), (16, 264), (17, 230), (18, 236), (18, 286), (19, 203), (20, 243), (20, 248), (20, 254), (22, 281), (24, 244), (24, 259), (24, 265), (25, 254), (26, 213), (26, 230), (26, 270), (28, 249), (28, 273), (29, 241), (31, 218), (31, 261), (32, 253), (34, 206), (34, 222), (34, 275), (35, 215), (36, 201), (38, 259), (39, 222), (40, 209), (40, 251), (40, 287), (42, 241), (43, 264), (49, 295), (50, 276), (51, 200), (51, 237), (52, 200), (54, 253), (55, 247), (55, 277), (56, 289), (57, 220), (58, 224), (58, 230), (59, 274), (60, 284), (60, 296), (61, 208), (61, 277), (62, 204), (63, 205), (64, 214), (64, 250), (66, 242), (69, 262), (69, 267), (69, 294), (70, 257), (70, 266), (70, 283), (70, 300), (72, 295), (73, 203), (73, 219), (73, 230), (73, 288), (74, 220), (74, 234), (74, 283), (74, 298), (75, 263), (75, 291), (78, 231), (80, 248), (80, 291), (82, 256), (83, 250), (85, 252), (85, 260), (87, 249), (87, 279), (87, 285), (88, 207), (88, 280), (89, 212), (91, 207), (91, 293), (92, 203), (92, 215), (92, 217), (92, 284), (92, 291), (94, 207), (94, 208), (94, 276), (94, 290), (95, 222), (95, 230), (96, 213), (97, 227), (97, 244), (97, 247), (100, 215), (100, 226), (103, 207), (106, 249), (107, 274), (109, 200), (109, 237), (110, 212), (110, 286), (111, 218), (112, 248), (113, 217), (114, 232), (114, 264), (115, 203), (116, 287)]
x1 = [x[0] for x in l0] 
y1 = [x[1] for x in l0] 
plt.scatter(x1, y1, color = "red")
l1 = [(10, 244), (12, 213), (19, 203), (36, 201), (51, 200)]
x2 = [x[0] for x in l1] 
y2 = [x[1] for x in l1] 
plt.scatter(x2, y2, color = "blue")
plt.xlabel("Distance")
plt.ylabel("Fee")
plt.show()

from scipy.spatial import ConvexHull, convex_hull_plot_2d
points = np.array(l0)  # 30 random points in 2-D
hull = ConvexHull(points)
import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], 'o')
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
plt.plot(points[hull.vertices,0], points[hull.vertices,1], lw=2)
plt.plot(points[hull.vertices[0],0], points[hull.vertices[0],1], 'ro')
plt.title("Convex Haul")
plt.xlabel("Distance")
plt.ylabel("Fee")
plt.show()

# %%
hull.vertices
# Out:
# array([  1,   0,   4,  15,  37,  47, 120, 129, 130,  73], dtype=int32)
